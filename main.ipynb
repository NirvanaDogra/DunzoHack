# %%
# !pip install opencv-python
# Out:
# ...
# WARNING: You are using pip version 19.1.1, however version 19.2.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import cv2
import numpy as np

img = cv2.imread('bill1.jpeg')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

lines = cv2.HoughLines(edges,1,np.pi/180,200)
for rho,theta in lines[0]:
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a*rho
    y0 = b*rho
    x1 = int(x0 + 1000*(-b))
    y1 = int(y0 + 1000*(a))
    x2 = int(x0 - 1000*(-b))
    y2 = int(y0 - 1000*(a))

    cv2.line(img,(x1,y1),(x2,y2),(0,0,255),2)

cv2.imwrite('houghlines3.jpg',img)
# Out:
# True

# %%
import base64
import json
import os

from google.cloud import pubsub_v1
from google.cloud import storage
from google.cloud import translate
from google.cloud import vision

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]=r"C:\Users\Nirvan Dogra\Desktop\my\GoogleOCR.json"
 GOOGLE_APPLICATION_CREDENTIALS=C:\Users\Nirvan Dogra\Desktop\my\GoogleOCR.json

# %%
import io;
from google.cloud import vision
from google.cloud import vision
processText=[];
file=open("rawOutput.txt", "a");
# %matplotlib inline

def binarize_and_preprocess(filename):
    
    import numpy as np
    
    img=cv2.imread(filename,0)
    img_orig=img

    (thresh, im_bw) = cv2.threshold(img, 0, 255, cv2.THRESH_TOZERO+cv2.THRESH_OTSU)#| cv2.THRESH_OTSU)
    import matplotlib.pyplot as plt
    
    plt.figure(figsize=(25,10))
    
    plt.subplot(1,2,1), plt.imshow(im_bw,'gray')
    plt.title("New image")
    plt.xticks([]),plt.yticks([])
    plt.show()
    
    plt.figure(figsize=(25,10))
    
    plt.subplot(1,2,2), plt.imshow(img_orig,'gray')
    plt.title("Old image")
    plt.xticks([]),plt.yticks([])
    plt.show()
    return im_bw

def detect_text(path):
    """Detects text in the file."""
    import matplotlib.pyplot as plt
    
    
#     return im_bw
    
    client = vision.ImageAnnotatorClient()
    
    #content = binarize_and_preprocess(path)
    with io.open(path, 'rb') as image_file:
        content = image_file.read()

    image = vision.types.Image(content=content)

    response = client.text_detection(image=image)
    texts = response.text_annotations
    print('Texts:')

    for text in texts:
        processText.append(text.description)
        file.write(text.description)
        
        break;
#         print('\n"{}"'.format(text.description))

#         vertices = (['({},{})'.format(vertex.x, vertex.y)
#                     for vertex in text.bounding_poly.vertices])

#         print('bounds: {}'.format(','.join(vertices)))

# %%
for i in range(0,325):
    path="food/bill%s"%i+".jpeg";
    try:
        i=detect_text(path)
    except:
        pass
#     break
    
    print("done", i)
    file.write("\n--------------------------------\n");
file.close()
# Out:
# done 0
# done 1
# done 2
# done 3
# done 4
# done 5
# done 6
# done 7
# done 8
# done 9
# done 10
# done 11
# done 12
# done 13
# done 14
# done 15
# done 16
# done 17
# done 18
# done 19
# done 20
# done 21
# done 22
# done 23
# done 24
# done 25
# done 26
# done 27
# done 28
# done 29
# done 30
# done 31
# done 32
# done 33
# done 34
# done 35
# done 36
# done 37
# done 38
# done 39
# done 40
# done 41
# done 42
# done 43
# done 44
# done 45
# done 46
# done 47
# done 48
# done 49
# done 50
# done 51
# done 52
# done 53
# done 54
# done 55
# done 56
# done 57
# done 58
# done 59
# done 60
# done 61
# done 62
# done 63
# done 64
# done 65
# done 66
# done 67
# done 68
# done 69
# done 70
# done 71
# done 72
# done 73
# done 74
# done 75
# done 76
# done 77
# done 78
# done 79
# done 80
# done 81
# done 82
# done 83
# done 84
# done 85
# done 86
# done 87
# done 88
# done 89
# done 90
# done 91
# done 92
# done 93
# done 94
# done 95
# done 96
# done 97
# done 98
# done 99
# ...

# %%
print("Title", list[0:4])
print(list)
# Out:
# Title ['30', 'IV', 'NOBILE SUPER BAZZARG', 'M.R ARGADE']
# ['30', 'IV', 'NOBILE SUPER BAZZARG', 'M.R ARGADE', 'NO:172, NEH TIPPASANDRA MAIN ROAD', 'HAL 3rd STAGE, BANGALORE 560075', 'PH: 7406893060', 'Mar 5, 2017', '16: 12:11', 'Bill No:8128387 BIL', '29668005062NTL', 'Item Naime', 'PRICE', 'TDTAL', 'MTR MECRONT 500', 'GOOD LIFE 500ML', 'PULPY ORANGE', 'NILG MOZZA CHE', '40.00', '23.00', "00'1", '23.00', '00 0E', '00', 'AMUL CHEEZ SLIC', 'BREAD', 'O0 02', '67.00 1.00', '00 02', 'OC 19', 'OD SE', 'MTR MECRONI 500', 'COKE DIET 330ML', 'COVERS', '40.00 1.00', '30.00', '00', '30.00', '009', 'DD S', '100', 'Grand Total', 'Tatal Item', 'Total Qty', 'Payment Type:', '0', '130.04', 'Exempted Sale', 'VAT 85.5 On', '9.87', '97.00', '']

# %%
import requests
from bs4 import BeautifulSoup
import re    
 
def getResults(search):
    p = re.compile('[0-9 \.]*') 
    
    if(len(p.findall(search)[0].strip())>0) :
        print(p.findall(search))
        return False;
        
    page = requests.get("https://www.bigbasket.com/ps/?q=" + search)
    soup = BeautifulSoup(page.content, "html.parser")
    data=page.text   
    movie_containers = soup.find_all('script')[5]   
    my=(str(movie_containers).split(" "))
    #Index=(my.index('"ResultsCount":'))
    print(str(movie_containers).split(" "))
    if  '\\"No'  in my  and 'results' in my:
        index=my.index('"SearchTerm":')+1;
        autoC=""
        
        while my[index]!='"ResultsCount":':
            autoC+=" "+my[index]
            index+=1;
        print(autoC)
        return False, autoC

    else:
        print("product found")
        return True

# %%
getResults("unty")
# Out:
# ['<script>\n', '', '', '', 'var', 'globalChannel', '=', "'';\n", '', '', '', 'var', 'loggedInUser', '=', 'false;\n', '', '', '', 'var', 'ctype', '=', "'customtemplates';\n", '', '', '', 'var', 'tlc', '=', 'null;\n', '', '', '', 'var', 'sid', '=', 'null;\n', '', '', '', 'var', 'snowplow_type', '=', 'null;\n', '', '', '', '\n', '', '', '', '', '', '', '', '\n', '', '', '', '', '', '', '', '', '', '', '', 'snowplow_type', '=', '\'{"EventName":', '"Ps_Shown",', '"ResultsCount":', '292,', '"ScreenType":', '"ps",', '"ScreenTypeID":', '""}\';\n', '', '', '', '', '', '', '', '\n', '', '', '', '\n', '', '', '', '\n', '', '', '', 'var', 'customPageURL', '=', "'';\n", '', '', '', 'var', 'slug', '=', 'null;\n', '', '', '', '\n', '', '', '', '', '', '', '', 'slug', '=', "'unty';\n", '', '', '', '\n', '', '', '', '\n', '', '', '', '', '', '', '', 'sid', '=', "'KOPrto2pYmF0Y2hfaWR4AKFjA6JuZsOoc2t1X2xpc3SQomFvwqJ1csKhcaR1bnR5omFww6JsdM0RbKFvqXJlbGV2YW5jZaVzcl9pZAGkaXNfasOjbXJpAg==';\n", '', '', '', 
# ...

# %%
client = MongoClient() 
client = MongoClient('localhost', 27017)
client = MongoClient("mongodb://localhost:27017/") 

mydatabase = client["DunzoDB"] 

mycollection = mydatabase.myTable4

# %%
file=open("rawOutput.txt", "r");
count=0
add=""
for lines in file.readlines():
    if '--------------------------------\n' in lines:        
        count=0
        
    if count<5:
        add+=lines;        
        count+=1;
        continue;
        
        
    else: 
        try:
            if getResults(lines)==True:
                rec = mycollection.insert_one({"Address": add.split("\n")[0], "Product Name":lines.strip()}) 
            else:
                n,val= getResults(lines)
                mycollection.insert_one({"Address": add.split("\n")[0], "Product Name":val}) 
                
        except:
            pass
        
    
file.close()
# Out:
# ['<script>\n', '', '', '', 'var', 'globalChannel', '=', "'';\n", '', '', '', 'var', 'loggedInUser', '=', 'false;\n', '', '', '', 'var', 'ctype', '=', "'customtemplates';\n", '', '', '', 'var', 'tlc', '=', 'null;\n', '', '', '', 'var', 'sid', '=', 'null;\n', '', '', '', 'var', 'snowplow_type', '=', 'null;\n', '', '', '', '\n', '', '', '', '', '', '', '', '\n', '', '', '', '', '', '', '', '', '', '', '', 'snowplow_type', '=', '\'{"EventName":', '"Ps_Shown",', '"ResultsCount":', '488,', '"ScreenType":', '"ps",', '"ScreenTypeID":', '""}\';\n', '', '', '', '', '', '', '', '\n', '', '', '', '\n', '', '', '', '\n', '', '', '', 'var', 'customPageURL', '=', "'';\n", '', '', '', 'var', 'slug', '=', 'null;\n', '', '', '', '\n', '', '', '', '', '', '', '', 'slug', '=', "'Mar+5%2C+2017%0A';\n", '', '', '', '\n', '', '', '', '\n', '', '', '', '', '', '', '', 'sid', '=', "'MqT-Do2pYmF0Y2hfaWR4AKFjA6JuZsOoc2t1X2xpc3SQomFvwqJ1csOhcaptYXIgNSAyMDE3omFww6JsdM0RbKFvqXJlbGV2YW5jZaVzcl9pZAGkaXNfasOjbXJpAg=
# ...

# %%
cursor = mycollection.find({"Address":"NOBILE SUPER BAZZARG"}) 
# for record in cursor: 
#     print(record) 
for document in mycollection.find():
    
    if "total" == document["Product Name"].lower():
        print(document["Product Name"])
        print(mycollection.delete_one(document["_id"]))

# %%
dic={}
for document in mycollection.find():
    if document["Address"] not in dic.keys():
        dic[document["Address"]]=[document["Product Name"]]
    else:
        dic[document["Address"]].append(document["Product Name"])

# %%
file=open("Menu.txt", "a+")


for i in dic.keys():
    print("The Shop :", i)
    file.write(i)
    file.write(",\n");
    print("Menu :\n")
    for j in set(dic[i]) :
        file.write(j);
        file.write("\n");
        
        print(j)
file.close()
# Out:
# The Shop : NOBILE SUPER BAZZARG
# Menu :
#
#
#  "ooty",
# AMUL BUTTER 100
# NO Ite
# Andunt
#  "executive",
#  "aer",
# em
#  "vatika",
# PULPY ORANGE
#  "exotic",
#  "valai",
#  "and",
#  "britannia treat biscuit",
#  "yam",
# PRICE
# Grand Totar PAID
# Exenpted Sale :
# Thanks for Shopp ing
#  "cup noodles chicken",
# UAT 14 S
# e8-
# un
#  "scale",
# PICETY10TAL
# Feb 7, 2017
#  "shandong",
# COVERS
# On
# MTR CHILLS POWDER 10
# SURF EXCEL MATIC 500
#  "cashew",
# TDTAL
# unty
#  "face shop",
# DD S
#  "aarti",
# VAT 5X On 00
# TAX
# BL1T No:8129395BL
# ewithinswo daysree Home Delivery
#  "bathroom brushes",
# OD SE
# AT S S
# ice
# Bark
#  "cerelac",
# DETTOL LIQ HAND WASH
# BREAD
# SCISSOR 1
# UAT 814.53 On: 90.00
# VAT 5X On
# Qty
# SCYNG7
# ICE CREAM
# VAT 5% On
#  "cigar",
# Mar 2
# N30 100
# Tatat aty
# Cash
# QTY
# MAP Rats
# SONA MASOURI 1KG
# PAID
# HR
# AMUL BUTTER MILK
#  "tal",
#  "spf 15",
# VAT @14% On
# *** Thanks for Shopping **

# %%
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS as stopwords 
from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.metrics import accuracy_score 
from sklearn.base import TransformerMixin 
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
import spacy
import en_core_web_sm
import string
punctuations = string.punctuation

parser = spacy.load("en")

#Custom transformer using spaCy 
class predictors(TransformerMixin):
    def transform(self, X, **transform_params):
        return [clean_text(text) for text in X]
    def fit(self, X, y=None, **fit_params):
        return self
    def get_params(self, deep=True):
        return {}

# Basic utility function to clean the text 
def clean_text(text):     
    return text.strip().lower()

# %%
#Create spacy tokenizer that parses a sentence and generates tokens
#these can also be replaced by word vectors 
def spacy_tokenizer(sentence):
    tokens = parser(sentence)
    tokens = [tok.lemma_.lower().strip() if tok.lemma_ != "-PRON-" else tok.lower_ for tok in tokens]
    tokens = [tok for tok in tokens if (tok not in stopwords and tok not in punctuations)]
    return tokens

#create vectorizer object to generate feature vectors, we will use custom spacy’s tokenizer
vectorizer = CountVectorizer(tokenizer = spacy_tokenizer, ngram_range=(1,1)) 
classifier = LinearSVC()

# %%
pipe = Pipeline([("cleaner", predictors()),
                 ('vectorizer', vectorizer),
                 ('classifier', classifier)])
for x in dic.values():
    print(x)
# pipe.fit(x for x in dic.values(), 1)
# Out:
# ['PRICE', 'TDTAL', 'PULPY ORANGE', 'BREAD', 'OD SE', 'COVERS', 'DD S', '', ' "cashew",', 'em', 'unty', 'VAT 5X On 00', 'ewithinswo daysree Home Delivery', '', 'QTY', 'PRICE', ' "cashew",', 'On', ' "yam",', '', 'Feb 7, 2017', 'PRICE', ' "ooty",', ' "britannia treat biscuit",', 'e8-', ' "cashew",', 'Thanks for Shopp ing', '', ' "tal",', 'AMUL BUTTER 100', 'ICE CREAM', 'Grand Totar PAID', ' "aer",', '', 'SURF EXCEL MATIC 500', 'DETTOL LIQ HAND WASH', 'AMUL BUTTER MILK', 'COVERS', ' "cashew",', 'VAT 5% On', '', 'PRICE', ' "ooty",', ' "shandong",', 'SONA MASOURI 1KG', 'MTR CHILLS POWDER 10', 'COVERS', ' "cashew",', ' "vatika",', '', 'PRICE', 'SCISSOR 1', 'SCISSOR 1', 'COVERS', 'un', ' "face shop",', '', 'Mar 2', 'COVERS', ' "cashew",', 'Exenpted Sale :', 'UAT 814.53 On: 90.00', '', ' "cashew",', 'VAT 5X On', ' "vatika",', '', 'TAX', 'ice', 'N30 100', ' "cerelac",', 'NO Ite', 'Qty', 'MAP Rats', ' "valai",', 'Tatat aty', 'PAID', ' "scale",', ' "bathroom brushes",', ' "cup noodles chicken",'
# ...
